# %% [markdown]
# # Weather forecast from notebook
#
# Import this notebook from PROJECT -> Create -> From notebook. AGILAB will clone `weather_forecast_project` and create `weather_forecast_from_notebook_project`. Each runnable cell is tagged as an AGILAB manager cell so the import can proceed without role guessing.

# %% [markdown]
# ## Load the daily weather snapshot
#
# Seed or load the local Meteo-France-style CSV snapshot and keep one station on a stable daily timeline.

# %%
APP = 'weather_forecast_project'
station = 'Paris-Montsouris'
target_column = 'tmax_c'

# %% [markdown]
# ## Configure the recursive forecasting frame
#
# Prepare the lag-based forecasting problem with a small validation window and a short prediction horizon.

# %%
lags = 7
validation_days = 9
horizon_days = 7

# %% [markdown]
# ## Backtest the skforecast forecaster
#
# Run a recursive RandomForest forecaster on the validation window and compute MAE, RMSE, and MAPE.

# %% [markdown]
# ## Export reusable analysis artifacts
#
# Write forecast_predictions.csv and forecast_metrics.json so ANALYSIS can compare runs without reopening the notebook kernel.

# %%
artifact_dir = '~/export/weather_forecast/forecast_analysis'
