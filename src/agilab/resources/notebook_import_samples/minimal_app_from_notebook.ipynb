# %% [markdown]
# # MinimalApp from notebook
#
# Import this notebook from PROJECT -> Create -> From notebook. AGILAB will clone `minimal_app_project` and create `minimal_app_from_notebook_project`. Each runnable cell is tagged as an AGILAB manager cell so the import can proceed without role guessing.

# %% [markdown]
# ## Run the minimal minimal_app smoke
#
# Install and execute the minimal minimal_app worker with a local scheduler and one worker.

# %%
APP = 'minimal_app_project'
scheduler = '127.0.0.1'
workers = {'127.0.0.1': 1}
mode = 'python_or_dask_smoke'
