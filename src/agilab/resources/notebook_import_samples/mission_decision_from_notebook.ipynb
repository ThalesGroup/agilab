# %% [markdown]
# # Mission decision from notebook
#
# Import this notebook from PROJECT -> Create -> From notebook. AGILAB will clone `mission_decision_project` and create `mission_decision_from_notebook_project`. Each runnable cell is tagged as an AGILAB manager cell so the import can proceed without role guessing.

# %% [markdown]
# ## Ingest mission data
#
# Load the public Mission Decision scenario with sensor, satcom, constraint inputs, and deterministic FRED context evidence.

# %%
APP = 'mission_decision_project'
data_in = 'mission_decision/scenarios'
files = '*.json'

# %% [markdown]
# ## Generate the adaptive pipeline
#
# Select the required cleaning, feature, scoring, failure-detection, re-planning, and decision stages from the scenario contract.

# %%
APP = 'mission_decision_project'
failure_kind = 'bandwidth_drop'
adaptation_mode = 'auto_replan'

# %% [markdown]
# ## Distribute scenario execution
#
# Partition mission scenario files across available workers and produce worker-visible metadata.

# %%
APP = 'mission_decision_project'
workers = {'127.0.0.1': 1}

# %% [markdown]
# ## Optimize the routing decision
#
# Score candidate routes against latency, cost, reliability, and risk constraints.

# %%
APP = 'mission_decision_project'
objective = 'balanced_mission'

# %% [markdown]
# ## Inject failure and re-plan
#
# Apply a bandwidth-drop event to the initially selected route, recompute candidate scores, and select the adapted strategy.

# %%
APP = 'mission_decision_project'
failure_kind = 'bandwidth_drop'

# %% [markdown]
# ## Export final decision evidence
#
# Write the summary metrics, generated pipeline, decision timeline, and route comparison artifacts for ANALYSIS.

# %%
APP = 'mission_decision_project'
data_out = 'mission_decision/results'
