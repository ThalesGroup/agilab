# %% [markdown]
# # Mycode from notebook
#
# Import this notebook from PROJECT -> Create -> From notebook. AGILAB will clone `mycode_project` and create `mycode_from_notebook_project`. Each runnable cell is tagged as an AGILAB manager cell so the import can proceed without role guessing.

# %% [markdown]
# ## Run the minimal mycode smoke
#
# Install and execute the minimal mycode worker with a local scheduler and one worker.

# %%
APP = 'mycode_project'
scheduler = '127.0.0.1'
workers = {'127.0.0.1': 1}
mode = 'python_or_dask_smoke'
