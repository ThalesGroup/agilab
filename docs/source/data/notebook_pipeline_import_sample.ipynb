# %% [markdown]
# # Flight import context
#
# Load a checked-in CSV and prepare an AGILAB pipeline step.

# %%
from pathlib import Path
import pandas as pd

input_path = Path("data/flights.csv")
flights = pd.DataFrame({"speed": [220, 240], "aircraft": ["A", "B"]})
flights.to_csv(input_path, index=False)

# %% [markdown]
# ## Analysis context
#
# Summarize the imported records and name output artifacts.

# %%
import json

summary_path = "artifacts/summary.json"
plot_path = "artifacts/trajectory.png"
summary = {"rows": 2, "plot": plot_path}
Path(summary_path).write_text(json.dumps(summary), encoding="utf-8")
